# %%
python3 get-pip.py

# %%
import requests

URL = "https://pokeapi.co/api/v2/pokemon/pikachu"
response = requests.get(URL)
if response.status_code == 200:
    print('Solicitud exitosa')
    print('Data:', response.json())
else:
    print('Error en la solicitud, detalles:', response.text)

# %% [markdown]
# Pasar el json a un diccionario para poder trabajarlo mejor
# En python existe le modulo 'json' en donde nos convierte objetos JSON a string JSON

# %%
import requests
import json


URL = "https://pokeapi.co/api/v2/pokemon/pikachu"
response = requests.get(URL)
data = response.json()

data_identada = json.dumps(data, indent=4)

# for clave, valor in data.items():
#     print(f"{clave}: {valor}\n")

print(data_identada)

# print(data)
print(type(data))
#print('Error en la solicitud, detalles:', response.text)

# %%
import requests
import json


URL = "https://pokeapi.co/api/v2/pokemon/pikachu"
response = requests.get(URL)
data = response.json()

for clave, valor in data.items():
     print(f"{clave}:\n")
     print(json.dumps(valor, indent=4))

# %%
import requests


URL = "https://pokeapi.co/api/v2/pokemon/pikachu"
response = requests.get(URL)
data = response.json()

for pokemon in data:
     print(data["name"])
